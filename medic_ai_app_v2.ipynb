# %%
#mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/MsDSAI/Code/NLP/
# Out:
# /content/drive/My Drive/MsDSAI/Code/NLP

# %%
# !git clone https://github.com/MyaMjechal/medic-ai.git

# %%
# %cd medic-ai/
# Out:
# /content/drive/My Drive/MsDSAI/Code/NLP/medic-ai

# %%
# !git pull
# Out:
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 10 (delta 6), reused 9 (delta 5), pack-reused 0 (from 0)
# Unpacking objects: 100% (10/10), 999 bytes | 1024 bytes/s, done.
# From https://github.com/MyaMjechal/medic-ai
#    50ddfbc..315f3c1  main       -> origin/main
# Updating 50ddfbc..315f3c1
# Fast-forward
#  app/code/app.py               | 75 +++++++++++++------------------------------
#  app/code/medicine_scanning.py |  4 +--
#  2 files changed, 25 insertions(+), 54 deletions(-)

# %%
# %cd app/code/
# Out:
# /content/drive/My Drive/MsDSAI/Code/NLP/medic-ai/app/code

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 MB 46.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.6/322.6 kB 26.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 121.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 61.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 45.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 20.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 74.5 MB/s eta 0:00:00
# ...

# %%
import os
os.environ['HUGGINGFACE_TOKEN'] = "TOKEN"

# %%
DRIVE_FOLDER = "/content/drive/My Drive/MsDSAI/January 2025/NLP/Project/Data/"
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = os.path.join(DRIVE_FOLDER, "google-cloud-service-key.json")

# %%
from pyngrok import ngrok

# Set authtoken
# !ngrok config add-authtoken TOKEN
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
os.environ['NGROK_SKIP_BROWSER_WARNING'] = 'true'

# %%
# Open a public URL for port 8050
public_url = ngrok.connect(addr="8050", proto="http")
print("Public URL:", public_url)
# Out:
# Public URL: NgrokTunnel: "https://4d13-35-240-203-166.ngrok-free.app" -> "http://localhost:8050"

# %%
# !python app.py
# Out:
# 2025-04-28 06:29:15.800831: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-28 06:29:15.818050: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745821755.839197   13582 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745821755.845681   13582 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
